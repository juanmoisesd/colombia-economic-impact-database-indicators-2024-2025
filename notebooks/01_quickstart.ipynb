# %% [markdown]
# # Quickstart: Colombia Economic Impact Database
# This notebook provides a quick overview of the dataset.

# %%
import pandas as pd
df_dict = pd.read_csv('../data_dictionary.csv')
df_dict.head()
